# %% [markdown]
# # Zad 1

# %%
from sklearn.manifold import TSNE
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# wczytywanie i dzielenie
digits = load_digits()
x = digits.data
y = digits.target
print(f"X: {x}")
print(f"Y: {y}")
# Out:
# X: [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# Y: [0 1 2 ... 8 9 8]

# %%
#scaler = StandardScaler()
#x = scaler.fit_transform(x)

# %%
# Stosowanie PCA
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x)
# Wyświetlenie nowych danych po zastosowaniu PCA
print("Nowe dane po zastosowaniu PCA:")
print(x_pca)
# Out:
# Nowe dane po zastosowaniu PCA:
# [[ -1.25946555  21.27488372]
#  [  7.95761302 -20.76869915]
#  [  6.99192128  -9.95598633]
#  ...
#  [ 10.80128328  -6.96025187]
#  [ -4.87209714  12.42395419]
#  [ -0.34439164   6.36554941]]

# %%
plt.figure(figsize=(8, 6))
scatter = plt.scatter(x_pca[:, 0], x_pca[:, 1], c=y, cmap='hsv', edgecolor='k', alpha=0.7)
plt.title('Wyniki PCA dla datasetu Digits')
plt.xlabel('Składowa główna 1')
plt.ylabel('Składowa główna 2')
plt.grid(True)
# Dodanie legendy z etykietami klas
plt.colorbar(scatter, label='Target')
plt.show()

# %%
# PCA słabo się sprawia lepszy jest LDA
# Stosowanie TSNE
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(x)
# Wyświetlenie nowych danych po zastosowaniu TSNE
print("Nowe dane po zastosowaniu TSNE:")
print(X_tsne)
# Out:
# Nowe dane po zastosowaniu TSNE:
# [[ -2.6966796  52.958584 ]
#  [ 10.160706  -11.921371 ]
#  [-13.777729  -18.540272 ]
#  ...
#  [ -5.5154986 -10.805379 ]
#  [-20.96892    15.382157 ]
#  [-14.192224   -6.9067335]]

# %% [markdown]
# # Wnioski
# PCA słabo się sprawia w tym zadaniu z powodu zastosowania techniki liniowej

# %%
# Wykres wyników TSNE
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='hsv', edgecolor='k', alpha=0.7)
plt.title('Wyniki analizy głównych składowych (TSNE) dla datasetu Digits')
plt.xlabel('Składowa główna 1')
plt.ylabel('Składowa główna 2')
plt.grid(True)
# Dodanie legendy z etykietami klas
plt.colorbar(scatter, label='Target')
plt.show()

# %% [markdown]
# # Wnioski
# Możemy zobaczyć dokładnie wydzielone klasy dla T-sne
